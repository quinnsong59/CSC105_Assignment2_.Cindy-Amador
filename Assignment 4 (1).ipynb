# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("drive/My Drive/Notebooks/data/travel_tourism_dataset.csv")

# %%
df
# Out:
#       Trip #no.  Duration  Cost of Travel(Entire Trip) Mode of Travel  \
# 0            55         1                        20111         Flight
# 1           288         5                        29681            Car
# 2           291         7                        24950         Flight
# 3           131        19                        18676       Roadtrip
# 4           281        28                        18899         Flight
# ...         ...       ...                          ...            ...
# 2995        142        24                        17801       Roadtrip
# 2996        265        16                        23410          Train
# 2997        232        22                         5656       Roadtrip
# 2998        112        15                        27509            Car
# 2999        283        13                        19865         Cruise
#
#          Stay First Name   Last Name Date of Birth  \
# 0       Hotel   Cristina     Fuentes    1914-06-14
# ...

# %%
df.shape
# Out:
# (3000, 13)

# %%
df.columns
# Out:
# Index(['Trip #no.', 'Duration', 'Cost of Travel(Entire Trip)',
#        'Mode of Travel', 'Stay', 'First Name', 'Last Name', 'Date of Birth',
#        'Address', 'Age', 'Sex', 'Nationality', 'Date of Travel'],
#       dtype='object')

# %%
df['Age']
# Out:
# 0       74
# 1       19
# 2       36
# 3       38
# 4       38
#         ..
# 2995    73
# 2996    50
# 2997    36
# 2998    48
# 2999    22
# Name: Age, Length: 3000, dtype: int64

# %%
df['Stay']
# Out:
# 0         Hotel
# 1         Hotel
# 2        Airbnb
# 3        Airbnb
# 4        Airbnb
#          ...
# 2995    Resorts
# 2996      Hotel
# 2997      Hotel
# 2998     Airbnb
# 2999     Airbnb
# Name: Stay, Length: 3000, dtype: object

# %%
df['Cost of Travel(Entire Trip)']
# Out:
# 0       20111
# 1       29681
# 2       24950
# 3       18676
# 4       18899
#         ...
# 2995    17801
# 2996    23410
# 2997     5656
# 2998    27509
# 2999    19865
# Name: Cost of Travel(Entire Trip), Length: 3000, dtype: int64

# %%
df['First Name']
# Out:
# 0        Cristina
# 1        Patricia
# 2       Christina
# 3         Michael
# 4       Francisco
#           ...
# 2995        Kerry
# 2996        Kevin
# 2997      William
# 2998       Marcus
# 2999          Tom
# Name: First Name, Length: 3000, dtype: object

# %%
df['Last Name']
# Out:
# 0          Fuentes
# 1            Young
# 2            Kirby
# 3           Hudson
# 4          Hensley
#            ...
# 2995         Allen
# 2996       Johnson
# 2997    Mclaughlin
# 2998           Ray
# 2999      Fletcher
# Name: Last Name, Length: 3000, dtype: object

# %%
df.loc[df['Age']<30]
# Out:
#       Trip #no.  Duration  Cost of Travel(Entire Trip) Mode of Travel  \
# 1           288         5                        29681            Car
# 6           173         8                        16642         Flight
# 8           154        27                        25299            Car
# 18            7        19                        25750       Roadtrip
# 22           56        24                        10551         Flight
# ...         ...       ...                          ...            ...
# 2962        197        29                        18250         Flight
# 2973          3        26                        19775            Car
# 2976        181        18                        28957       Roadtrip
# 2977          6         8                        11479            Bus
# 2999        283        13                        19865         Cruise
#
#          Stay First Name  Last Name Date of Birth  \
# 1       Hotel   Patricia      Young    1923-09-25
# ...

# %%
df2=df.loc[df['Age']<30]

# %%
df2
# Out:
#       Trip #no.  Duration  Cost of Travel(Entire Trip) Mode of Travel  \
# 1           288         5                        29681            Car
# 6           173         8                        16642         Flight
# 8           154        27                        25299            Car
# 18            7        19                        25750       Roadtrip
# 22           56        24                        10551         Flight
# ...         ...       ...                          ...            ...
# 2962        197        29                        18250         Flight
# 2973          3        26                        19775            Car
# 2976        181        18                        28957       Roadtrip
# 2977          6         8                        11479            Bus
# 2999        283        13                        19865         Cruise
#
#          Stay First Name  Last Name Date of Birth  \
# 1       Hotel   Patricia      Young    1923-09-25
# ...

# %%
df.loc[(df['Age']<30) & (df['Stay'] == "Hotel")]
# Out:
#       Trip #no.  Duration  Cost of Travel(Entire Trip) Mode of Travel   Stay  \
# 1           288         5                        29681            Car  Hotel
# 50          216        28                        28339            Car  Hotel
# 56          164         8                        15728          Train  Hotel
# 71          256        11                        17377            Bus  Hotel
# 90          257        10                         5881          Train  Hotel
# ...         ...       ...                          ...            ...    ...
# 2810        174         1                        22963            Bus  Hotel
# 2819         73        24                        13476         Cruise  Hotel
# 2860        173         1                        26676            Bus  Hotel
# 2866        159         1                        13803       Roadtrip  Hotel
# 2899         47         3                        15401         Flight  Hotel
#
#        First Name Last Name Date of Birth  \
# ...

# %%
df3=df.loc[(df['Age']<30) & (df['Stay'] == "Hotel")]
df3
# Out:
#       Trip #no.  Duration  Cost of Travel(Entire Trip) Mode of Travel   Stay  \
# 1           288         5                        29681            Car  Hotel
# 50          216        28                        28339            Car  Hotel
# 56          164         8                        15728          Train  Hotel
# 71          256        11                        17377            Bus  Hotel
# 90          257        10                         5881          Train  Hotel
# ...         ...       ...                          ...            ...    ...
# 2810        174         1                        22963            Bus  Hotel
# 2819         73        24                        13476         Cruise  Hotel
# 2860        173         1                        26676            Bus  Hotel
# 2866        159         1                        13803       Roadtrip  Hotel
# 2899         47         3                        15401         Flight  Hotel
#
#        First Name Last Name Date of Birth  \
# ...

# %%
df.loc[(df['Age']<30) & (df['Stay'] == "Hotel") & (df['Cost of Travel(Entire Trip)']<6000)]
# Out:
#       Trip #no.  Duration  Cost of Travel(Entire Trip) Mode of Travel   Stay  \
# 90          257        10                         5881          Train  Hotel
# 299         188         9                         5233            Bus  Hotel
# 714         100        15                         5601            Bus  Hotel
# 1638        218        24                         5744          Train  Hotel
# 1932        294         3                         5648       Roadtrip  Hotel
# 1936        221        25                         5631          Train  Hotel
#
#      First Name Last Name Date of Birth  \
# 90      Charles    Holden    1970-07-24
# 299     Brandon  Stafford    1983-10-02
# 714       Julie     Young    1958-09-11
# 1638       Sean    Norman    1917-03-19
# 1932    Jessica     Payne    1948-01-13
# 1936   Jennifer    Miller    2012-04-23
#
#                                                 Address  Age          Sex  \
# ...

# %%
df4=df.loc[(df['Age']<30) & (df['Stay'] == "Hotel") & (df['Cost of Travel(Entire Trip)']<6000)]

# %%
df4
# Out:
#       Trip #no.  Duration  Cost of Travel(Entire Trip) Mode of Travel   Stay  \
# 90          257        10                         5881          Train  Hotel
# 299         188         9                         5233            Bus  Hotel
# 714         100        15                         5601            Bus  Hotel
# 1638        218        24                         5744          Train  Hotel
# 1932        294         3                         5648       Roadtrip  Hotel
# 1936        221        25                         5631          Train  Hotel
#
#      First Name Last Name Date of Birth  \
# 90      Charles    Holden    1970-07-24
# 299     Brandon  Stafford    1983-10-02
# 714       Julie     Young    1958-09-11
# 1638       Sean    Norman    1917-03-19
# 1932    Jessica     Payne    1948-01-13
# 1936   Jennifer    Miller    2012-04-23
#
#                                                 Address  Age          Sex  \
# ...

# %% [markdown]
# This was so much fun! In Group A there were 598 tourists under the age of 30,in Group B there were 146 tourist who stayed in hotel and were under the age of 30, and finally in Group C there were 6 potentials and only 1 was from China and her name is **Jennifer Mille**r.
